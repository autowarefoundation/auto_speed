# %% [markdown]
# # auto_speed

# %% [markdown]
# ## I. Getting Started Guide

# %% [markdown]
# ### 1. auto_speed model introduction

# %% [markdown]
# auto_speed is a specialized object detection model in VisionPilot for **closest in-path object (CIPO)** detection, used to support speed control and safe following distance decisions. The implementation is inspired by a YOLO-style one-stage detector and is optimized for real-time operation with a default input size of **$1024 $** x **$512$**.
#
# The network follows a **Backbone => Neck (FPN/PAN-style fusion) => Detection Head** design:
#
# - **AutoSpeed Backbone** : extracts multi-scale features (`p3`, `p4`, `p5`) through progressive downsampling. Unlike a standard block stack, it introduces the **AutoSpeed Context block** in multiple stages to inject global context and improve CIPO localization robustness.
#
# - **AutoSpeed Neck** : upsamples and fuses features across scales using `C3K2` and convolution blocks, combining high-level semantics with lower-level spatial detail before prediction.
#
# - **AutoSpeed Head** : predicts bounding boxes and class logits at three feature scales. It uses **Distribution Focal Loss box regression** and decodes predictions into final boxes during inference.
#
# In the current training/inference configuration, AutoSpeed is built with `num_classes = 4`, with class names in `auto_speed.yaml`: `NA`, `CIPO-1`, `CIPO-2`, and `CIPO-3`. During inference, predictions are post-processed with confidence filtering and NMS, then projected back to the original image coordinates from the letterboxed input.

# %% [markdown]
# ![](../../Media/auto_speed.gif)

# %% [markdown]
# ### 2. Environment Setup

# %% [markdown]
# **If you have done these steps of environment setup in other End-to-End Model Tutorials, please skip this and move forward to the next subsection `3. Download Models`.**

# %% [markdown]
# First, we need to clone the repository to your local environment. We will use the official repository from the
# Autoware Foundation.

# %%
import os

base_dir = os.getcwd()

# Clone auto_speed repo, if not yet done
if not os.path.exists("./auto_speed"):
    # !git clone https://github.com/autowarefoundation/auto_speed.git
# Out:
# Cloning into 'auto_speed'...
# remote: Enumerating objects: 68, done.
# remote: Counting objects: 100% (8/8), done.
# remote: Compressing objects: 100% (8/8), done.
# remote: Total 68 (delta 0), reused 0 (delta 0), pack-reused 60 (from 1)
# Receiving objects: 100% (68/68), 50.10 MiB | 35.35 MiB/s, done.
# Resolving deltas: 100% (1/1), done.

# %% [markdown]
# The auto_speed project relies on several key libraries, including **PyTorch** for model execution and
# **OpenCV** for image processing.
#
# We will use `pip` to install the required dependencies directly from the `requirements.txt` file provided in
# the `Models` directory.

# %%
# Install required dependencies
# %pip install --upgrade pip
# %pip install -r ../../requirements.txt

# Verify the installation (checking torch as a primary dependency)
import torch
print(f"PyTorch version: {torch.__version__}")
print(f"CUDA availability: {torch.cuda.is_available()}")
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Requirement already satisfied: pip in /data/DEVELOPMENT/AUTONOMOUS/AUTOWARE/auto_speed/.venv/lib/python3.11/site-packages (26.1.2)
# Note: you may need to restart the kernel to use updated packages.
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Requirement already satisfied: h5py>=3.0 in /data/DEVELOPMENT/AUTONOMOUS/AUTOWARE/auto_speed/.venv/lib/python3.11/site-packages (from -r ../../requirements.txt (line 1)) (3.16.0)
# Requirement already satisfied: albumentations>=1.4.18 in /data/DEVELOPMENT/AUTONOMOUS/AUTOWARE/auto_speed/.venv/lib/python3.11/site-packages (from -r ../../requirements.txt (line 2)) (2.0.8)
# Requirement already satisfied: cmapy>=0.6.6 in /data/DEVELOPMENT/AUTONOMOUS/AUTOWARE/auto_speed/.venv/lib/python3.11/site-packages (from -r ../../requirements.txt (line 3)) (0.6.6)
# Requirement already satisfied: matplotlib>=3.8.0 in /data/DEVELOPMENT/AUTONOMOUS/AUTOWARE/auto_speed/.venv/lib/python3.11/site-packages (from -r ../../requirements.txt (line 4)) (3.11.0)
# Requirement already satisfied: numpy<2.0.0,>=1.21.0 in /data/DEVELOPMENT/AUTONOMOUS/AUTOWARE/auto_speed/.venv/lib/python3.11/site-packages (from -r ../../requirements.txt (line 5)) (1.26.4)
# Requirement already satisfied: onnx>=1.17.0 in /data/DEVELOPMENT/AUTONOMOUS/AUTOWARE/auto_speed/.venv/lib/python3.11/site-packages (from -r ../../requirements.txt (line 6)) (1.22.0)
# Requirement already satisfied: onnxruntime>=1.21.0 in /data/DEVELOPMENT/AUTONOMOUS/AUTOWARE/auto_speed/.venv/lib/python3.11/site-packages (from -r ../../requirements.txt (line 7)) (1.27.0)
# Requirement already satisfied: opencv-contrib-python>=4.10.0.84 in /data/DEVELOPMENT/AUTONOMOUS/AUTOWARE/auto_speed/.venv/lib/python3.11/site-packages (from -r ../../requirements.txt (line 8)) (4.11.0.86)
# Requirement already satisfied: opencv-python>=4.10.0.84 in /data/DEVELOPMENT/AUTONOMOUS/AUTOWARE/auto_speed/.venv/lib/python3.11/site-packages (from -r ../../requirements.txt (line 9)) (4.11.0.86)
# Requirement already satisfied: opencv-python-headless>=4.11.0.86 in /data/DEVELOPMENT/AUTONOMOUS/AUTOWARE/auto_speed/.venv/lib/python3.11/site-packages (from -r ../../requirements.txt (line 10)) (4.11.0.86)
# Requirement already satisfied: Pillow>=11.3.0 in /data/DEVELOPMENT/AUTONOMOUS/AUTOWARE/auto_speed/.venv/lib/python3.11/site-packages (from -r ../../requirements.txt (line 11)) (12.2.0)
# Requirement already satisfied: scikit-learn in /data/DEVELOPMENT/AUTONOMOUS/AUTOWARE/auto_speed/.venv/lib/python3.11/site-packages (from -r ../../requirements.txt (line 12)) (1.9.0)
# Requirement already satisfied: pytorch-model-summary>=0.1.2 in /data/DEVELOPMENT/AUTONOMOUS/AUTOWARE/auto_speed/.venv/lib/python3.11/site-packages (from -r ../../requirements.txt (line 13)) (0.1.2)
# Requirement already satisfied: thop>=0.1.1.post2209072238 in /data/DEVELOPMENT/AUTONOMOUS/AUTOWARE/auto_speed/.venv/lib/python3.11/site-packages (from -r ../../requirements.txt (line 14)) (0.1.1.post2209072238)
# Requirement already satisfied: torch>=2.7.0 in /data/DEVELOPMENT/AUTONOMOUS/AUTOWARE/auto_speed/.venv/lib/python3.11/site-packages (from -r ../../requirements.txt (line 15)) (2.12.0)
# Requirement already satisfied: torchvision>=0.22.0 in /data/DEVELOPMENT/AUTONOMOUS/AUTOWARE/auto_speed/.venv/lib/python3.11/site-packages (from -r ../../requirements.txt (line 16)) (0.27.0)
# Requirement already satisfied: tensorboard>=2.20.0 in /data/DEVELOPMENT/AUTONOMOUS/AUTOWARE/auto_speed/.venv/lib/python3.11/site-packages (from -r ../../requirements.txt (line 17)) (2.20.0)
# Requirement already satisfied: tensorboard-data-server>=0.7.2 in /data/DEVELOPMENT/AUTONOMOUS/AUTOWARE/auto_speed/.venv/lib/python3.11/site-packages (from -r ../../requirements.txt (line 18)) (0.7.2)
# Requirement already satisfied: scipy>=1.10.0 in /data/DEVELOPMENT/AUTONOMOUS/AUTOWARE/auto_speed/.venv/lib/python3.11/site-packages (from albumentations>=1.4.18->-r ../../requirements.txt (line 2)) (1.17.1)
# Requirement already satisfied: PyYAML in /data/DEVELOPMENT/AUTONOMOUS/AUTOWARE/auto_speed/.venv/lib/python3.11/site-packages (from albumentations>=1.4.18->-r ../../requirements.txt (line 2)) (6.0.3)
# Requirement already satisfied: pydantic>=2.9.2 in /data/DEVELOPMENT/AUTONOMOUS/AUTOWARE/auto_speed/.venv/lib/python3.11/site-packages (from albumentations>=1.4.18->-r ../../requirements.txt (line 2)) (2.13.4)
# Requirement already satisfied: albucore==0.0.24 in /data/DEVELOPMENT/AUTONOMOUS/AUTOWARE/auto_speed/.venv/lib/python3.11/site-packages (from albumentations>=1.4.18->-r ../../requirements.txt (line 2)) (0.0.24)
# Requirement already satisfied: stringzilla>=3.10.4 in /data/DEVELOPMENT/AUTONOMOUS/AUTOWARE/auto_speed/.venv/lib/python3.11/site-packages (from albucore==0.0.24->albumentations>=1.4.18->-r ../../requirements.txt (line 2)) (4.6.2)
# Requirement already satisfied: simsimd>=5.9.2 in /data/DEVELOPMENT/AUTONOMOUS/AUTOWARE/auto_speed/.venv/lib/python3.11/site-packages (from albucore==0.0.24->albumentations>=1.4.18->-r ../../requirements.txt (line 2)) (6.5.16)
# Requirement already satisfied: contourpy>=1.0.1 in /data/DEVELOPMENT/AUTONOMOUS/AUTOWARE/auto_speed/.venv/lib/python3.11/site-packages (from matplotlib>=3.8.0->-r ../../requirements.txt (line 4)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /data/DEVELOPMENT/AUTONOMOUS/AUTOWARE/auto_speed/.venv/lib/python3.11/site-packages (from matplotlib>=3.8.0->-r ../../requirements.txt (line 4)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /data/DEVELOPMENT/AUTONOMOUS/AUTOWARE/auto_speed/.venv/lib/python3.11/site-packages (from matplotlib>=3.8.0->-r ../../requirements.txt (line 4)) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /data/DEVELOPMENT/AUTONOMOUS/AUTOWARE/auto_speed/.venv/lib/python3.11/site-packages (from matplotlib>=3.8.0->-r ../../requirements.txt (line 4)) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /data/DEVELOPMENT/AUTONOMOUS/AUTOWARE/auto_speed/.venv/lib/python3.11/site-packages (from matplotlib>=3.8.0->-r ../../requirements.txt (line 4)) (26.2)
# Requirement already satisfied: pyparsing>=3 in /data/DEVELOPMENT/AUTONOMOUS/AUTOWARE/auto_speed/.venv/lib/python3.11/site-packages (from matplotlib>=3.8.0->-r ../../requirements.txt (line 4)) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /data/DEVELOPMENT/AUTONOMOUS/AUTOWARE/auto_speed/.venv/lib/python3.11/site-packages (from matplotlib>=3.8.0->-r ../../requirements.txt (line 4)) (2.9.0.post0)
# Requirement already satisfied: protobuf>=4.25.1 in /data/DEVELOPMENT/AUTONOMOUS/AUTOWARE/auto_speed/.venv/lib/python3.11/site-packages (from onnx>=1.17.0->-r ../../requirements.txt (line 6)) (7.35.1)
# Requirement already satisfied: typing_extensions>=4.15.0 in /data/DEVELOPMENT/AUTONOMOUS/AUTOWARE/auto_speed/.venv/lib/python3.11/site-packages (from onnx>=1.17.0->-r ../../requirements.txt (line 6)) (4.15.0)
# Requirement already satisfied: ml_dtypes>=0.5.4 in /data/DEVELOPMENT/AUTONOMOUS/AUTOWARE/auto_speed/.venv/lib/python3.11/site-packages (from onnx>=1.17.0->-r ../../requirements.txt (line 6)) (0.5.4)
# Requirement already satisfied: flatbuffers in /data/DEVELOPMENT/AUTONOMOUS/AUTOWARE/auto_speed/.venv/lib/python3.11/site-packages (from onnxruntime>=1.21.0->-r ../../requirements.txt (line 7)) (25.12.19)
# Requirement already satisfied: joblib>=1.4.0 in /data/DEVELOPMENT/AUTONOMOUS/AUTOWARE/auto_speed/.venv/lib/python3.11/site-packages (from scikit-learn->-r ../../requirements.txt (line 12)) (1.5.3)
# Requirement already satisfied: narwhals>=2.0.1 in /data/DEVELOPMENT/AUTONOMOUS/AUTOWARE/auto_speed/.venv/lib/python3.11/site-packages (from scikit-learn->-r ../../requirements.txt (line 12)) (2.22.1)
# Requirement already satisfied: threadpoolctl>=3.5.0 in /data/DEVELOPMENT/AUTONOMOUS/AUTOWARE/auto_speed/.venv/lib/python3.11/site-packages (from scikit-learn->-r ../../requirements.txt (line 12)) (3.6.0)
# Requirement already satisfied: tqdm in /data/DEVELOPMENT/AUTONOMOUS/AUTOWARE/auto_speed/.venv/lib/python3.11/site-packages (from pytorch-model-summary>=0.1.2->-r ../../requirements.txt (line 13)) (4.68.2)
# Requirement already satisfied: filelock in /data/DEVELOPMENT/AUTONOMOUS/AUTOWARE/auto_speed/.venv/lib/python3.11/site-packages (from torch>=2.7.0->-r ../../requirements.txt (line 15)) (3.29.4)
# Requirement already satisfied: setuptools<82 in /data/DEVELOPMENT/AUTONOMOUS/AUTOWARE/auto_speed/.venv/lib/python3.11/site-packages (from torch>=2.7.0->-r ../../requirements.txt (line 15)) (81.0.0)
# Requirement already satisfied: sympy>=1.13.3 in /data/DEVELOPMENT/AUTONOMOUS/AUTOWARE/auto_speed/.venv/lib/python3.11/site-packages (from torch>=2.7.0->-r ../../requirements.txt (line 15)) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /data/DEVELOPMENT/AUTONOMOUS/AUTOWARE/auto_speed/.venv/lib/python3.11/site-packages (from torch>=2.7.0->-r ../../requirements.txt (line 15)) (3.6.1)
# Requirement already satisfied: jinja2 in /data/DEVELOPMENT/AUTONOMOUS/AUTOWARE/auto_speed/.venv/lib/python3.11/site-packages (from torch>=2.7.0->-r ../../requirements.txt (line 15)) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /data/DEVELOPMENT/AUTONOMOUS/AUTOWARE/auto_speed/.venv/lib/python3.11/site-packages (from torch>=2.7.0->-r ../../requirements.txt (line 15)) (2026.6.0)
# Requirement already satisfied: cuda-toolkit==13.0.2 in /data/DEVELOPMENT/AUTONOMOUS/AUTOWARE/auto_speed/.venv/lib/python3.11/site-packages (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=2.7.0->-r ../../requirements.txt (line 15)) (13.0.2)
# Requirement already satisfied: nvidia-cublas<=13.1.1.3,>=13.1.0.3 in /data/DEVELOPMENT/AUTONOMOUS/AUTOWARE/auto_speed/.venv/lib/python3.11/site-packages (from torch>=2.7.0->-r ../../requirements.txt (line 15)) (13.1.1.3)
# Requirement already satisfied: cuda-bindings<14,>=13.0.3 in /data/DEVELOPMENT/AUTONOMOUS/AUTOWARE/auto_speed/.venv/lib/python3.11/site-packages (from torch>=2.7.0->-r ../../requirements.txt (line 15)) (13.3.1)
# Requirement already satisfied: nvidia-cudnn-cu13==9.20.0.48 in /data/DEVELOPMENT/AUTONOMOUS/AUTOWARE/auto_speed/.venv/lib/python3.11/site-packages (from torch>=2.7.0->-r ../../requirements.txt (line 15)) (9.20.0.48)
# Requirement already satisfied: nvidia-cusparselt-cu13==0.8.1 in /data/DEVELOPMENT/AUTONOMOUS/AUTOWARE/auto_speed/.venv/lib/python3.11/site-packages (from torch>=2.7.0->-r ../../requirements.txt (line 15)) (0.8.1)
# Requirement already satisfied: nvidia-nccl-cu13==2.29.7 in /data/DEVELOPMENT/AUTONOMOUS/AUTOWARE/auto_speed/.venv/lib/python3.11/site-packages (from torch>=2.7.0->-r ../../requirements.txt (line 15)) (2.29.7)
# Requirement already satisfied: nvidia-nvshmem-cu13==3.4.5 in /data/DEVELOPMENT/AUTONOMOUS/AUTOWARE/auto_speed/.venv/lib/python3.11/site-packages (from torch>=2.7.0->-r ../../requirements.txt (line 15)) (3.4.5)
# Requirement already satisfied: triton==3.7.0 in /data/DEVELOPMENT/AUTONOMOUS/AUTOWARE/auto_speed/.venv/lib/python3.11/site-packages (from torch>=2.7.0->-r ../../requirements.txt (line 15)) (3.7.0)
# Requirement already satisfied: nvidia-cuda-runtime==13.0.96.* in /data/DEVELOPMENT/AUTONOMOUS/AUTOWARE/auto_speed/.venv/lib/python3.11/site-packages (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=2.7.0->-r ../../requirements.txt (line 15)) (13.0.96)
# Requirement already satisfied: nvidia-cufft==12.0.0.61.* in /data/DEVELOPMENT/AUTONOMOUS/AUTOWARE/auto_speed/.venv/lib/python3.11/site-packages (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=2.7.0->-r ../../requirements.txt (line 15)) (12.0.0.61)
# Requirement already satisfied: nvidia-cufile==1.15.1.6.* in /data/DEVELOPMENT/AUTONOMOUS/AUTOWARE/auto_speed/.venv/lib/python3.11/site-packages (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=2.7.0->-r ../../requirements.txt (line 15)) (1.15.1.6)
# Requirement already satisfied: nvidia-cuda-cupti==13.0.85.* in /data/DEVELOPMENT/AUTONOMOUS/AUTOWARE/auto_speed/.venv/lib/python3.11/site-packages (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=2.7.0->-r ../../requirements.txt (line 15)) (13.0.85)
# Requirement already satisfied: nvidia-curand==10.4.0.35.* in /data/DEVELOPMENT/AUTONOMOUS/AUTOWARE/auto_speed/.venv/lib/python3.11/site-packages (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=2.7.0->-r ../../requirements.txt (line 15)) (10.4.0.35)
# Requirement already satisfied: nvidia-cusolver==12.0.4.66.* in /data/DEVELOPMENT/AUTONOMOUS/AUTOWARE/auto_speed/.venv/lib/python3.11/site-packages (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=2.7.0->-r ../../requirements.txt (line 15)) (12.0.4.66)
# Requirement already satisfied: nvidia-cusparse==12.6.3.3.* in /data/DEVELOPMENT/AUTONOMOUS/AUTOWARE/auto_speed/.venv/lib/python3.11/site-packages (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=2.7.0->-r ../../requirements.txt (line 15)) (12.6.3.3)
# Requirement already satisfied: nvidia-nvjitlink==13.0.88.* in /data/DEVELOPMENT/AUTONOMOUS/AUTOWARE/auto_speed/.venv/lib/python3.11/site-packages (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=2.7.0->-r ../../requirements.txt (line 15)) (13.0.88)
# Requirement already satisfied: nvidia-cuda-nvrtc==13.0.88.* in /data/DEVELOPMENT/AUTONOMOUS/AUTOWARE/auto_speed/.venv/lib/python3.11/site-packages (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=2.7.0->-r ../../requirements.txt (line 15)) (13.0.88)
# Requirement already satisfied: nvidia-nvtx==13.0.85.* in /data/DEVELOPMENT/AUTONOMOUS/AUTOWARE/auto_speed/.venv/lib/python3.11/site-packages (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=2.7.0->-r ../../requirements.txt (line 15)) (13.0.85)
# Requirement already satisfied: cuda-pathfinder>=1.4.2 in /data/DEVELOPMENT/AUTONOMOUS/AUTOWARE/auto_speed/.venv/lib/python3.11/site-packages (from cuda-bindings<14,>=13.0.3->torch>=2.7.0->-r ../../requirements.txt (line 15)) (1.5.5)
# Requirement already satisfied: absl-py>=0.4 in /data/DEVELOPMENT/AUTONOMOUS/AUTOWARE/auto_speed/.venv/lib/python3.11/site-packages (from tensorboard>=2.20.0->-r ../../requirements.txt (line 17)) (2.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /data/DEVELOPMENT/AUTONOMOUS/AUTOWARE/auto_speed/.venv/lib/python3.11/site-packages (from tensorboard>=2.20.0->-r ../../requirements.txt (line 17)) (1.81.1)
# Requirement already satisfied: markdown>=2.6.8 in /data/DEVELOPMENT/AUTONOMOUS/AUTOWARE/auto_speed/.venv/lib/python3.11/site-packages (from tensorboard>=2.20.0->-r ../../requirements.txt (line 17)) (3.10.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /data/DEVELOPMENT/AUTONOMOUS/AUTOWARE/auto_speed/.venv/lib/python3.11/site-packages (from tensorboard>=2.20.0->-r ../../requirements.txt (line 17)) (3.1.8)
# Requirement already satisfied: annotated-types>=0.6.0 in /data/DEVELOPMENT/AUTONOMOUS/AUTOWARE/auto_speed/.venv/lib/python3.11/site-packages (from pydantic>=2.9.2->albumentations>=1.4.18->-r ../../requirements.txt (line 2)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /data/DEVELOPMENT/AUTONOMOUS/AUTOWARE/auto_speed/.venv/lib/python3.11/site-packages (from pydantic>=2.9.2->albumentations>=1.4.18->-r ../../requirements.txt (line 2)) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /data/DEVELOPMENT/AUTONOMOUS/AUTOWARE/auto_speed/.venv/lib/python3.11/site-packages (from pydantic>=2.9.2->albumentations>=1.4.18->-r ../../requirements.txt (line 2)) (0.4.2)
# Requirement already satisfied: six>=1.5 in /data/DEVELOPMENT/AUTONOMOUS/AUTOWARE/auto_speed/.venv/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib>=3.8.0->-r ../../requirements.txt (line 4)) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /data/DEVELOPMENT/AUTONOMOUS/AUTOWARE/auto_speed/.venv/lib/python3.11/site-packages (from sympy>=1.13.3->torch>=2.7.0->-r ../../requirements.txt (line 15)) (1.3.0)
# Requirement already satisfied: markupsafe>=2.1.1 in /data/DEVELOPMENT/AUTONOMOUS/AUTOWARE/auto_speed/.venv/lib/python3.11/site-packages (from werkzeug>=1.0.1->tensorboard>=2.20.0->-r ../../requirements.txt (line 17)) (3.0.3)
# Note: you may need to restart the kernel to use updated packages.
# PyTorch version: 2.12.0+cu130
# CUDA availability: True

# %% [markdown]
# ### 3. Download Models

# %% [markdown]
# You can manually download the model weight files, using the links below. Subsequent tutorial sections assume
# you already downloaded them and put them inside directory:
# `auto_speed/weights/`.
#
# **AutoSpeed 2.0 model weights - 2:1 aspect ratio, 512px by 1024px input image**
# - [Link to Download Pytorch Model Weights *.pth](https://drive.google.com/file/d/1L8oiuszUKFmLZxsgIp1wtzgSkj2pr6n7/view?usp=drive_link)
# - [Link to Download ONNX FP32 Weights *.onnx](https://drive.google.com/file/d/1bKYsnKbHD8DvQB2w3x6yu0Htup4KL2l5/view?usp=drive_link)
#
#
# You can also use below script block, which uses `gdown` to download above model weights into such default directory.

# %%
# %pip install gdown
import os
import gdown

base_dir = os.getcwd()

model_dir = "../weights"
if not os.path.exists(model_dir):
    os.makedirs(model_dir)

metadata = {
    "pth"   : {
        "url"       : "https://drive.google.com/uc?id=1L8oiuszUKFmLZxsgIp1wtzgSkj2pr6n7",
        "filepath"  : os.path.join(base_dir, model_dir, "autospeed.pth")
    },
    "onnx"  : {
        "url"       : "https://drive.google.com/uc?id=1bKYsnKbHD8DvQB2w3x6yu0Htup4KL2l5",
        "filepath"  : os.path.join(base_dir, model_dir, "autospeed.onnx")
    }
}

for weight_type in metadata:

    url         = metadata[weight_type]["url"]
    filepath    = metadata[weight_type]["filepath"]

    if not os.path.exists(filepath):
        print(f"Downloading AutoSpeed {weight_type} weights...")
        gdown.download(url, filepath, quiet = False)
    else:
        print(f"AutoSpeed {weight_type} weights already exist at {filepath}. Skipping download.")
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Requirement already satisfied: gdown in /data/DEVELOPMENT/AUTONOMOUS/AUTOWARE/auto_speed/.venv/lib/python3.11/site-packages (6.1.0)
# Requirement already satisfied: beautifulsoup4 in /data/DEVELOPMENT/AUTONOMOUS/AUTOWARE/auto_speed/.venv/lib/python3.11/site-packages (from gdown) (4.15.0)
# Requirement already satisfied: filelock in /data/DEVELOPMENT/AUTONOMOUS/AUTOWARE/auto_speed/.venv/lib/python3.11/site-packages (from gdown) (3.29.4)
# Requirement already satisfied: requests[socks] in /data/DEVELOPMENT/AUTONOMOUS/AUTOWARE/auto_speed/.venv/lib/python3.11/site-packages (from gdown) (2.34.2)
# Requirement already satisfied: tqdm in /data/DEVELOPMENT/AUTONOMOUS/AUTOWARE/auto_speed/.venv/lib/python3.11/site-packages (from gdown) (4.68.2)
# Requirement already satisfied: typing-extensions>=4.0 in /data/DEVELOPMENT/AUTONOMOUS/AUTOWARE/auto_speed/.venv/lib/python3.11/site-packages (from gdown) (4.15.0)
# Requirement already satisfied: soupsieve>=1.6.1 in /data/DEVELOPMENT/AUTONOMOUS/AUTOWARE/auto_speed/.venv/lib/python3.11/site-packages (from beautifulsoup4->gdown) (2.8.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /data/DEVELOPMENT/AUTONOMOUS/AUTOWARE/auto_speed/.venv/lib/python3.11/site-packages (from requests[socks]->gdown) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /data/DEVELOPMENT/AUTONOMOUS/AUTOWARE/auto_speed/.venv/lib/python3.11/site-packages (from requests[socks]->gdown) (3.18)
# Requirement already satisfied: urllib3<3,>=1.26 in /data/DEVELOPMENT/AUTONOMOUS/AUTOWARE/auto_speed/.venv/lib/python3.11/site-packages (from requests[socks]->gdown) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in /data/DEVELOPMENT/AUTONOMOUS/AUTOWARE/auto_speed/.venv/lib/python3.11/site-packages (from requests[socks]->gdown) (2026.5.20)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /data/DEVELOPMENT/AUTONOMOUS/AUTOWARE/auto_speed/.venv/lib/python3.11/site-packages (from requests[socks]->gdown) (1.7.1)
# Note: you may need to restart the kernel to use updated packages.
# Downloading AutoSpeed pth weights...
# Downloading...
# From: https://drive.google.com/uc?id=1L8oiuszUKFmLZxsgIp1wtzgSkj2pr6n7
# To: /data/DEVELOPMENT/AUTONOMOUS/AUTOWARE/auto_speed/Models/weights/autospeed.pth
# 100%|██████████| 18.9M/18.9M [00:00<00:00, 45.8MB/s]
# Downloading AutoSpeed onnx weights...
# Downloading...
# From: https://drive.google.com/uc?id=1bKYsnKbHD8DvQB2w3x6yu0Htup4KL2l5
# To: /data/DEVELOPMENT/AUTONOMOUS/AUTOWARE/auto_speed/Models/weights/autospeed.onnx
# 100%|██████████| 38.0M/38.0M [00:01<00:00, 20.2MB/s]

# %% [markdown]
# ## II. Quick Test/Inference

# %% [markdown]
# Pre-requisites: please ensure that you have completed the above **Environment Setup** first.

# %% [markdown]
# ### 1. Image Inference

# %% [markdown]
# The `image_visualization.py` script facilitates batch processing of images by loading a pre-trained model checkpoint, performing a forward pass on each image, and overlaying detected CIPO bounding boxes onto the original frames.

# %% [markdown]
# #### a. Run Batch Image Inference

# %% [markdown]
# To run this in any environment, we should navigate to the AutoSpeed visualization directory so the script's internal relative paths resolve correctly.
#
# Key Script Parameters:
# - `-p / --model_checkpoint_path`: location of your `.pth` file containing the trained weights.
# - `-i / --input_image_dirpath`: directory containing `.png`, `.jpg`, or `.jpeg` files to process.

# %%
# 1. Path declaration
# Here we use the previously downloaded Pytorch weight file.
# For input and output directories, you can change them to your preferred paths.
# For now we will use the default input and output directories provided in the repository.
import cv2
import matplotlib.pyplot as plt
from PIL import Image
from Models.inference.auto_speed_infer import AutoSpeedNetworkInfer

CHECKPOINT = metadata["pth"]["filepath"]
INPUT_IMG = os.path.join(
    base_dir,
    "./assets/images/highway_normal_1.png"
 )

# 2. Navigate to visualization directory and execute the script
checkpoint_abs = os.path.abspath(CHECKPOINT)
input_abs      = os.path.abspath(INPUT_IMG)

color_map = {1: (0, 0, 255), 2: (0, 255, 255), 3: (255, 255, 0)}

model = AutoSpeedNetworkInfer(checkpoint_abs)
img = Image.open(input_abs).convert("RGB")
prediction = model.inference(img)

img_cv = cv2.imread(input_abs)
for pred in prediction:
    x1, y1, x2, y2, conf, cls = pred
    color = color_map.get(int(cls), (255, 255, 255))
    x1, y1, x2, y2 = map(int, [x1, y1, x2, y2])
    cv2.rectangle(img_cv, (x1, y1), (x2, y2), color, 2)

img_rgb = cv2.cvtColor(img_cv, cv2.COLOR_BGR2RGB)
plt.figure(figsize=(12, 8))
plt.imshow(img_rgb)
plt.axis('off')
plt.show()  # renders inline in notebook
# Out:
# /data/DEVELOPMENT/AUTONOMOUS/AUTOWARE/auto_speed/.venv/lib/python3.11/site-packages/torch/functional.py:505: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at /pytorch/aten/src/ATen/native/TensorShape.cpp:4382.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]

# %% [markdown]
# ### 2. Video Inference

# %% [markdown]
# In this subsection, we apply the AutoSpeed model to video streams. The `video_visualization.py` script processes video files frame-by-frame, runs CIPO detection, and writes an annotated output video.
#
# The pipeline supports both **PyTorch** and **ONNX** model formats. It performs inference on each frame and overlays class-colored bounding boxes on detected in-path objects.

# %% [markdown]
# Key script parameters:
#
# - `-p / --model_checkpoint_path`: path to model (`.onnx`, `.pt`, or a directory for PyTorch inference).
# - `-i / --video_filepath`: path to the source video file.
# - `-o / --output_file`: output path prefix for the annotated video (script appends `.avi`).
# - `-v / --vis`: optional flag to preview frames during processing.

# %% [markdown]
# Technical details:
#
# - The script uses letterbox-style preprocessing inside the inference backend and maps detections back to original frame coordinates.
# - ONNX inference uses ONNX Runtime providers (`CUDAExecutionProvider`, fallback `CPUExecutionProvider`).
# - Output is encoded as MJPG and saved as `<output_file>.avi`, while preserving the source FPS and frame size.

# %%
import subprocess
from IPython.display import Video, display

# 1. Path declaration
# Similarly as image inference above:
# - Pytorch weight file (ONXX okay too).
# - Input/Output paths can be changed to preferred.
# - Using defaults for now.
MODEL_PATH = metadata["pth"]["filepath"]
INPUT_PATH = os.path.join(
    base_dir,
    "./assets/videos/highway_normal.mp4"
 )
OUTPUT_BASENAME = os.path.join(
    base_dir,
    "./results/highway_normal_output"
 )

# 2. Navigate to visualization directory and execute the script
# !mkdir results
# !cd ../visualizations/ && \
python3 video_visualization.py \
    -p {os.path.abspath(MODEL_PATH)} \
    -i {os.path.abspath(INPUT_PATH)} \
    -o {os.path.abspath(OUTPUT_BASENAME)}

print(f"Saved video: {os.path.abspath(OUTPUT_BASENAME)}.avi")
# Out:
# Loading PyTorch model...
# PyTorch Model Loaded
# Reading video frames
# Processing started
# /data/DEVELOPMENT/AUTONOMOUS/AUTOWARE/auto_speed/.venv/lib/python3.11/site-packages/torch/functional.py:505: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at /pytorch/aten/src/ATen/native/TensorShape.cpp:4382.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# Frame not read - ending processing
# Completed
# Saved video: /data/DEVELOPMENT/AUTONOMOUS/AUTOWARE/auto_speed/Models/tutorials/results/highway_normal_output.avi

# %% [markdown]
# ## III. Model Training

# %% [markdown]
# ### 1. Model Training on New Data

# %% [markdown]
# #### a. Load pre-trained model or load vanilla un-trained model for training from scratch

# %% [markdown]
# In this repository, AutoSpeed training is launched from `Models/training/auto_speed_trainer.py`, where the model is built with:
#
# ```python
# model = AutoSpeedNetwork().build_model(version=args.version, num_classes=4)
# ```
#
# By default, this means **vanilla training from scratch** (no checkpoint is loaded unless you add it).
#
# - **Train from scratch (current default behavior):** run the trainer as-is.
# - **Warm-start / fine-tune from a checkpoint:** use the existing helper `util.load_weight(model, ckpt)` with a small script edit.
#
# Use this pattern inside `train(...)` in `auto_speed_trainer.py` right after model creation:
#
# ```python
# # Option A: train from scratch
# CHECKPOINT_PATH = None
#
# # Option B: fine-tune from a pretrained AutoSpeed checkpoint
# CHECKPOINT_PATH = "/absolute/path/to/weights/.pth"
#
# model = AutoSpeedNetwork().build_model(version=args.version, num_classes=4)
# if CHECKPOINT_PATH is not None:
#     model = util.load_weight(model, CHECKPOINT_PATH)
# model.cuda()
# ```
#
# `util.load_weight` only loads parameters with matching names and shapes, which is useful when architectures are compatible but not strictly identical.
#
# Practical recommendation:
# - Start from scratch when your data distribution or class semantics differ significantly.
# - Start from checkpoint when you want faster convergence and more stable early training metrics.

# %% [markdown]
# #### b. Prepare the training datasets

# %% [markdown]
# AutoSpeed training in this repository is currently prepared around the OpenLane conversion pipeline under `Models/data_parsing/OpenLane/`.
#
# The converter script reorganizes and converts labels into YOLO format:
#
# ```
# <class_id> <x_center> <y_center> <width> <height>
# ```
#
# ### i) Expected raw structure before conversion
#
# `converter.py` expects these source folders under your dataset root:
#
# ```
# <DATASET_DIR>/
# ├── images/
# │   ├── training/
# │   └── validation/
# └── labels/
#     ├── training/
#     └── validation/
# ```
#
# ### ii) Run conversion
#
# From repository root:
#
# ```bash
# python3 Models/data_parsing/OpenLane/converter.py \
#   -d /absolute/path/to/openlane_autospeed_dataset
# ```
#
# What it does:
# - Moves images from `images/training` → `images/train`, and `images/validation` → `images/val`.
# - Converts JSON box labels into YOLO `.txt` labels in `labels/train` and `labels/val`.
# - Normalizes using fixed image size assumptions (`1920x1280`) from the converter script.
# - Maps class id `4` to `3` during conversion.
# - Expands training split by moving most validation samples into training (`expand_training_set(fract=0.25)` keeps ~25% in val).
#
# ### iii) Output structure used for training
#
# ```
# <DATASET_DIR>/
# ├── images/
# │   ├── train/
# │   └── val/
# └── labels/
#     ├── train/
#     └── val/
# ```
#
# ### iv) Quick sanity check for converted labels
#
# Use the visualization helper on a converted image:
#
# ```bash
# python3 Models/data_parsing/OpenLane/test_conversion.py \
#   -i /absolute/path/to/openlane_autospeed_dataset/images/train/<sample>.jpg
# ```
#
# This renders converted bounding boxes so you can quickly verify class/box alignment before training.

# %% [markdown]
# #### c. How to load dataset

# %% [markdown]
# `auto_speed_trainer.py` loads dataset samples from the root path provided by `--dataset` and expects this exact layout:
#
# ```
# <DATASET_DIR>/
# ├── images/
# │   ├── train/   # training images
# │   └── val/     # validation images
# └── labels/
#     ├── train/   # YOLO txt labels for train
#     └── val/     # YOLO txt labels for val
# ```
#
# The script discovers files from:
# - `Path(args.dataset + "/images/train/")` for training
# - `Path(args.dataset + "/images/val/")` for validation
#
# For each image path, label path is resolved by replacing `/images/` with `/labels/` and extension with `.txt`.
#
# ### Recommended checks before launch
#
# 1. Every image in `images/train` and `images/val` has a matching `.txt` in the corresponding labels folder.
# 2. Each label row has 5 values: `<class_id> <x_center> <y_center> <width> <height>`.
# 3. All box coordinates are normalized to `[0, 1]`.
# 4. Class ids match your configured classes in `Models/config/auto_speed.yaml`.
#
# ### Launch example (dataset loading from converted root)
#
# From `Models/training/`:
#
# ```bash
# python3 auto_speed_trainer.py \
#   --dataset /absolute/path/to/openlane_autospeed_dataset \
#   --batch-size 32 \
#   --epochs 30 \
#   --version n
# ```
#
# If you relabel or change dataset files, delete stale cache files (`images/train.cache`, `images/val.cache`) so labels are re-indexed correctly on the next run.

# %% [markdown]
# #### d. How to run training

# %% [markdown]
# After dataset conversion/preparation is complete, launch training with `auto_speed_trainer.py`.
#
# ##### i) Step 1: Confirm key inputs
#
# - `--dataset`: root path containing `images/train`, `images/val`, `labels/train`, `labels/val`.
# - `--version`: model scale (`n`, `s`, `m`, `l`, `x`).
# - `--input-size`, `--batch-size`, `--epochs`, and optional `--runs_dir`.
#
# The script loads hyperparameters from `Models/config/auto_speed.yaml`, builds `AutoSpeedNetwork`, profiles FLOPs/params, then starts train/val loops.
#
# ##### ii) Step 2: Run training
#
# From repository root:
#
# ```bash
# cd Models/training
# python3 auto_speed_trainer.py \
#   --dataset /absolute/path/to/openlane_autospeed_dataset \
#   --input-size 640 \
#   --batch-size 32 \
#   --epochs 30 \
#   --version n \
#   --runs_dir runs
# ```
#
# Optional multi-GPU launch (DDP):
#
# ```bash
# cd Models/training
# torchrun --nproc_per_node=2 auto_speed_trainer.py \
#   --dataset /absolute/path/to/openlane_autospeed_dataset \
#   --input-size 640 \
#   --batch-size 32 \
#   --epochs 30 \
#   --version n \
#   --runs_dir runs
# ```
#
# ##### iii) Step 3: What the script does during training
#
# - Builds training and validation loaders from `images/train` and `images/val`.
# - Applies augmentations (including mosaic/mixup with scheduled mosaic disable near the end).
# - Optimizes box/class/DFL losses with AMP and EMA.
# - Runs validation each epoch and reports mAP metrics.
# - Saves `last.pt` and best-performing `best.pt` under the run weights directory.
#
# ##### iv) Run outputs
#
# Each run is auto-created as `runs/runN/` with:
# - `runs/runN/weights/best.pt`
# - `runs/runN/weights/last.pt`
# - TensorBoard event logs for losses and metrics.

# %% [markdown]
# #### e. How to visualize training results

# %% [markdown]
# This training pipeline offers two practical result-inspection channels:
#
# 1. **TensorBoard logs** for epoch-level losses and validation metrics
# 2. **Saved checkpoints** (`best.pt`, `last.pt`) under each run directory
#
# ##### a) Open TensorBoard
#
# Run from `Models/training/` (or provide full path to runs):
#
# ```bash
# cd Models/training
# tensorboard --logdir runs --port 6006
# ```
#
# Then open `http://localhost:6006` in your browser.
#
# What you should see in Scalars:
# - `Loss/box`, `Loss/cls`, `Loss/dfl`
# - `Metrics/mAP`, `Metrics/mAP@50`, `Metrics/Recall`, `Metrics/Precision`
#
# ##### b) Inspect checkpoints and use them for inference
#
# During training, checkpoints are saved to:
# - `Models/training/runs/runN/weights/best.pt`
# - `Models/training/runs/runN/weights/last.pt`
#
# You can plug `best.pt` into the inference scripts from Section II to qualitatively check predictions on images/videos.
#
# Example (image inference expects checkpoint directory containing `best.pt`):
#
# ```bash
# cd Models/visualizations/
# python3 image_visualization.py \
#   -p /absolute/path/to/Models/training/runs/runN/weights \
#   -i /absolute/path/to/input_images \
#   -o /absolute/path/to/output_images
# ```
#
# Tip: compare outputs from multiple run folders (`run1`, `run2`, …) to track qualitative improvements across experiments.
